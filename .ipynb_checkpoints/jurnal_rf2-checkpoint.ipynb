# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import LabelEncoder
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, log_loss, precision_score, recall_score, f1_score, confusion_matrix, classification_report
import xgboost as xgb
from imblearn.over_sampling import SMOTE
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import roc_curve, auc, RocCurveDisplay

# %%
data = pd.read_csv('puskesmas.csv')
data[['Tekanan Sistolik', 'Tekanan Diastolik']] = data['Tekanan Darah'].str.split('/', expand=True)
data['Tekanan Sistolik'] = data['Tekanan Sistolik'].astype(int)
data['Tekanan Diastolik'] = data['Tekanan Diastolik'].astype(int)
data = data.drop(columns=['Tekanan Darah'])

# %%
kategori_columns = ['Jenis Kelamin', 'Riwayat Hipertensi', 'Riwayat Penyakit Jantung', 
                    'Sudah Menikah', 'Riwayat Stroke', 'Riwayat merokok']
for col in data.columns:
    if col not in kategori_columns:
        data[col] = pd.to_numeric(data[col], errors='coerce')

# %%
data['Jenis Kelamin'] = data['Jenis Kelamin'].replace({'Laki-laki':0,'Perempuan':1}).astype(np.uint8)
data['Riwayat Hipertensi'] = data['Riwayat Hipertensi'].replace({'tidak':0,'ya':1}).astype(np.uint8)
data['Riwayat Penyakit Jantung'] = data['Riwayat Penyakit Jantung'].replace({'tidak':0,'ya':1}).astype(np.uint8)
data['Sudah Menikah'] = data['Sudah Menikah'].replace({'tidak':0,'ya':1}).astype(np.uint8)
data['Riwayat Stroke'] = data['Riwayat Stroke'].replace({'tidak':0,'ya':1}).astype(np.uint8)
data['Riwayat merokok'] = data['Riwayat merokok'].replace({'tidak':0,'ya':1}).astype(np.uint8)
# Out:
# /tmp/ipykernel_5083/2592194176.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data['Jenis Kelamin'] = data['Jenis Kelamin'].replace({'Laki-laki':0,'Perempuan':1}).astype(np.uint8)
# /tmp/ipykernel_5083/2592194176.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data['Riwayat Hipertensi'] = data['Riwayat Hipertensi'].replace({'tidak':0,'ya':1}).astype(np.uint8)
# /tmp/ipykernel_5083/2592194176.py:3: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data['Riwayat Penyakit Jantung'] = data['Riwayat Penyakit Jantung'].replace({'tidak':0,'ya':1}).astype(np.uint8)
# /tmp/ipykernel_5083/2592194176.py:4: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data['Sudah Menikah'] = data['Sudah Menikah'].replace({'tidak':0,'ya':1}).astype(np.uint8)
# /tmp/ipykernel_5083/2592194176.py:5: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data['Riwayat Stroke'] = data['Riwayat Stroke'].replace({'tidak':0,'ya':1}).astype(np.uint8)
# /tmp/ipykernel_5083/2592194176.py:6: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data['Riwayat merokok'] = data['Riwayat merokok'].replace({'tidak':0,'ya':1}).astype(np.uint8)

# %%
data['Riwayat Stroke'].value_counts()
# Out:
# Riwayat Stroke
# 0    183
# 1     37
# Name: count, dtype: int64

# %%
class_occur = data['Riwayat Stroke'].value_counts()
class_names = ['No Stroke','Stroke']
fig, ax = plt.subplots()
ax.pie(class_occur, labels=class_names, autopct='%1.2f%%',
        shadow=True, startangle=0, counterclock=False)
ax.axis('equal')
ax.set_title('Class distribution')
plt.show()
print("# samples associated with no stroke: {}".format(class_occur[0]))
print("# samples associated with stroke: {}".format(class_occur[1]))
# Out:
# # samples associated with no stroke: 183
# # samples associated with stroke: 37

# %%
X = data[['Jenis Kelamin', 'Usia', 'Riwayat Hipertensi', 
        'Riwayat Penyakit Jantung', 'Sudah Menikah', 'Berat Badan', 
        'Riwayat merokok', 'Detak Jantung', 'Saturasi Oksigen', 
        'Suhu Tubuh', 'Tekanan Sistolik', 'Tekanan Diastolik']]
y = data['Riwayat Stroke']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.7, random_state=42)

# %%
clf = RandomForestClassifier(
    n_estimators=100,
    max_depth=5,
    oob_score=True,
    random_state=42
)

# %%
clf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(max_depth=5, oob_score=True, random_state=42)

# %%
# Normal
y_pred = clf.predict(X_test)

# Print OOB score
print(f"OOB score (Normal): {clf.oob_score_:.3f}")

# Confusion matrix
print("Confusion Matrix (Normal):")
print(confusion_matrix(y_test, y_pred))

# Detailed metrics
print("\nClassification Report (Normal):")
print(classification_report(y_test, y_pred))
# Out:
# OOB score (Normal): 0.877
# Confusion Matrix (Normal):
# [[55  0]
#  [ 9  2]]
#
# Classification Report (Normal):
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.92        55
#            1       1.00      0.18      0.31        11
#
#     accuracy                           0.86        66
#    macro avg       0.93      0.59      0.62        66
# weighted avg       0.88      0.86      0.82        66

# %%
y_proba = clf.predict_proba(X_test)[:, 1]

fpr, tpr, thresholds = roc_curve(y_test, y_proba)

j_scores = tpr - fpr
optimal_idx = np.argmax(j_scores)
optimal_threshold = thresholds[optimal_idx]

print(f"Optimal threshold (Youden's J): {optimal_threshold:.3f}")
print(f"At this threshold: TPR (sensitivity) = {tpr[optimal_idx]:.3f}, FPR = {fpr[optimal_idx]:.3f}")
# Out:
# Optimal threshold (Youden's J): 0.047
# At this threshold: TPR (sensitivity) = 0.909, FPR = 0.400

# %%
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, label='ROC curve')
plt.scatter(fpr[optimal_idx], tpr[optimal_idx], color='red', label=f'Optimal threshold = {optimal_threshold:.2f}', zorder=10)
plt.plot([0, 1], [0, 1], 'k--', lw=1)
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve with Optimal Threshold')
plt.legend(loc='lower right')
plt.grid(True)
plt.show()

# %%
# Smote
y_pred_optimal = (y_proba >= optimal_threshold).astype(int)

# Print OOB score
print(f"OOB score (Smote): {clf.oob_score_:.3f}")

# Confusion matrix
print("Confusion Matrix (Smote):")
print(confusion_matrix(y_test, y_pred_optimal))

# Detailed metrics
print("\nClassification Report (Smote):")
print(classification_report(y_test, y_pred_optimal))
# Out:
# OOB score (Smote): 0.877
# Confusion Matrix (Smote):
# [[33 22]
#  [ 1 10]]
#
# Classification Report (Smote):
#               precision    recall  f1-score   support
#
#            0       0.97      0.60      0.74        55
#            1       0.31      0.91      0.47        11
#
#     accuracy                           0.65        66
#    macro avg       0.64      0.75      0.60        66
# weighted avg       0.86      0.65      0.70        66
